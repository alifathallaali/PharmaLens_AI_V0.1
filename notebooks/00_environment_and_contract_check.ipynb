# %% [markdown]
# # 00_environment_and_contract_check
#
# This operational notebook uses the shared PharmaLens package and the canonical processed dataset.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd() / "src"))
from pharmalens.schema import CANONICAL_VERSION, REQUIRED_COLUMNS
print(CANONICAL_VERSION)
print(REQUIRED_COLUMNS)
