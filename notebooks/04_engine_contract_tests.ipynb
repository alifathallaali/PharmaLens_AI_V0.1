# %% [markdown]
# # 04_engine_contract_tests
#
# This operational notebook uses the shared PharmaLens package and the canonical processed dataset.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd() / "src"))
from pharmalens.data.io import load_canonical
from pharmalens.outputs.registry import EngineOutput
df = load_canonical()
EngineOutput("market", "1.0.0", df.head(10)).to_metadata()
