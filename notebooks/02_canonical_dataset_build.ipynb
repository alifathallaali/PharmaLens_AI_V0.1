# %% [markdown]
# # 02_canonical_dataset_build
#
# This operational notebook uses the shared PharmaLens package and the canonical processed dataset.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd() / "src"))
from pharmalens.data.processed import convert_processed_to_canonical
output, report = convert_processed_to_canonical("data/processed/cleaned_pharma_data.parquet")
print(output)
print(report)
