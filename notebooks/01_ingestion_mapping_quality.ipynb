# %% [markdown]
# # 01_ingestion_mapping_quality
#
# This operational notebook uses the shared PharmaLens package and the canonical processed dataset.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd() / "src"))
from pharmalens.data.processed import load_processed, adapt_processed
df = load_processed("data/processed/cleaned_pharma_data.parquet")
canonical, report = adapt_processed(df)
report
