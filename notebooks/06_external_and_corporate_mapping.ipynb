# %% [markdown]
# # 06_external_and_corporate_mapping
#
# This operational notebook uses the shared PharmaLens package and the canonical processed dataset.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd() / "src"))
print("Keep external and corporate sources separate; attach source_system, consent and provenance before merging.")
