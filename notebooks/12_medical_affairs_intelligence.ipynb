# %% [markdown]
# # PharmaLens AI — Medical Affairs Intelligence
# KOL mapping • Scientific landscape • Publications • Clinical trials • Competitor pipeline • Evidence • Medical education • Advisory boards • Medical × Commercial

# %%
from medical_affairs_intelligence import *

# %% [markdown]
# ## Integration
# Core Data Platform → Medical Affairs Data Layer → Intelligence Services → AI Copilot → Dashboards/Reports.
# Production: configurable weights, provenance, timestamps, confidence scores, audit logs and RBAC.
