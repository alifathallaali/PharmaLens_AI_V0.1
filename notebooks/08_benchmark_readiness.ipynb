# %% [markdown]
# # 08_benchmark_readiness
#
# This operational notebook uses the shared PharmaLens package and the canonical processed dataset.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd() / "src"))
print("Benchmarking is intentionally gated until consent, anonymization and cohort definitions are approved.")
